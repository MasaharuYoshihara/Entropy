# %%
import math
import pandas as pd

# n_All = 40
# 0 =< n_Ubi =< 40
# 0 =< n_Endo =< n_Ubi

num_min = 10
num_max = 40
n_total_app = []
n_Ubi_app = []
n_Int_app = []
I_Ubi_app = []
I_Int_app = []
delta_app = []

def comb(n, r):
    return math.factorial(n) / ((math.factorial(n - r) * math.factorial(r)))
def p(n, r):
    return comb(n, r) / pow(2, n)

for i in range(num_min, num_max + 1):
    for j in range(2, i + 1):
        for k in range(0, j + 1):
            n_total_app.append(i)
            n_Ubi_app.append(j)
            n_Int_app.append(k)
            I_Ubi_app.append(- math.log(p(i, j), 2))
            I_Int_app.append(- math.log(p(i, k), 2))
            delta_app.append(- math.log(p(i, k), 2) + math.log(p(i, j), 2))

n_total = pd.DataFrame(n_total_app, columns = ['Total'])           
n_Ubi = pd.DataFrame(n_Ubi_app, columns = ['Ubi'])
n_Int = pd.DataFrame(n_Int_app, columns = ['Int'])
i_Ubi = pd.DataFrame(I_Ubi_app, columns = ['Ubi Info'])
i_Int = pd.DataFrame(I_Int_app, columns = ['Int Info'])
i_delta = pd.DataFrame(delta_app, columns = ['delta'])
d = pd.concat([n_total, n_Ubi, n_Int, i_Ubi, i_Int, i_delta], axis = 1, join = "inner")

d
# Out:
#        Total  Ubi  Int   Ubi Info   Int Info      delta
# 0         10    2    0   4.508147  10.000000   5.491853
# 1         10    2    1   4.508147   6.678072   2.169925
# 2         10    2    2   4.508147   4.508147   0.000000
# 3         10    3    0   3.093109  10.000000   6.906891
# 4         10    3    1   3.093109   6.678072   3.584963
# ...      ...  ...  ...        ...        ...        ...
# 12023     40   40   36  40.000000  23.520251 -16.479749
# 12024     40   40   37  40.000000  26.729705 -13.270295
# 12025     40   40   38  40.000000  30.392670  -9.607330
# 12026     40   40   39  40.000000  34.678072  -5.321928
# 12027     40   40   40  40.000000  40.000000   0.000000
#
# [12028 rows x 6 columns]

# %%
#d.to_csv('Watabe_20240723.txt', sep='\t', index=True)

# %%
import math
import pandas as pd
import seaborn as sns

# Define the range for total number of applications
num_min = 10
num_max = 40

# Initialize lists to store data
n_total_app = []
n_Ubi_app = []
n_Int_app = []
I_Ubi_app = []
I_Int_app = []
delta_app = []

# Function to calculate combinations
def comb(n, r):
    return math.factorial(n) / (math.factorial(n - r) * math.factorial(r))

# Function to calculate probability
def p(n, r):
    return comb(n, r) / pow(2, n)

# Populate the lists with data
for i in range(num_min, num_max + 1):
    for j in range(2, i + 1):
        for k in range(0, j + 1):
            n_total_app.append(i)
            n_Ubi_app.append(j)
            n_Int_app.append(k)
            I_Ubi_app.append(- math.log(p(i, j), 2))
            I_Int_app.append(- math.log(p(i, k), 2))
            delta_app.append(- math.log(p(i, k), 2) + math.log(p(i, j), 2))

n_total = pd.DataFrame(n_total_app, columns = ['Total'])           
n_Ubi = pd.DataFrame(n_Ubi_app, columns = ['Ubi'])
n_Int = pd.DataFrame(n_Int_app, columns = ['Int'])
i_Ubi = pd.DataFrame(I_Ubi_app, columns = ['Ubi Info'])
i_Int = pd.DataFrame(I_Int_app, columns = ['Int Info'])
i_delta = pd.DataFrame(delta_app, columns = ['delta'])
d = pd.concat([n_total, n_Ubi, n_Int, i_Ubi, i_Int, i_delta], axis = 1, join = "inner")

sns.scatterplot(x="Total", y="delta", data=d)
sns.regplot(x="Total", y="delta", data=d)
# Out:
# <Axes: xlabel='Total', ylabel='delta'>

# %%
import math
import pandas as pd

# n_All = 40
# 0 =< n_Ubi =< 40
# 0 =< n_Endo =< n_Ubi

num_min = 10
num_max = 40
n_total_app = []
n_Ubi_app = []
n_Int_app = []
I_Ubi_app = []
I_Int_app = []
delta_app = []

def comb(n, r):
    return math.factorial(n) / ((math.factorial(n - r) * math.factorial(r)))
def p(n, r):
    return comb(n, r) / pow(2, n)

for i in range(num_min, num_max + 1):
    for j in range(2, i + 1):
        for k in range(0, j + 1):
            n_total_app.append(i)
            n_Ubi_app.append(j)
            n_Int_app.append(k)
            I_Ubi_app.append(- math.log(p(i, j), 2))
            I_Int_app.append(- math.log(p(i, k), 2))
            delta_app.append(- math.log(p(i, k), 2) + math.log(p(i, j), 2))

n_total = pd.DataFrame(n_total_app, columns = ['Total'])           
n_Ubi = pd.DataFrame(n_Ubi_app, columns = ['Ubi'])
n_Int = pd.DataFrame(n_Int_app, columns = ['Int'])
i_Ubi = pd.DataFrame(I_Ubi_app, columns = ['Ubi Info'])
i_Int = pd.DataFrame(I_Int_app, columns = ['Int Info'])
i_delta = pd.DataFrame(delta_app, columns = ['delta'])

import matplotlib.pyplot as plt
sns.set_style("darkgrid")

X = n_total
Y = i_Ubi
Z = i_Int

from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = Axes3D(fig)

ax.set_xlabel("Total")
ax.set_ylabel("Ubi Info")
ax.set_zlabel("Int Info")

ax.plot(X,Y,Z,marker="o",linestyle='None')

plt.show()

# %%
import math
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# Define the range for total number of applications
num_min = 10
num_max = 40

# Initialize lists to store data
n_total_app = []
n_Ubi_app = []
n_Int_app = []
I_Ubi_app = []
I_Int_app = []
delta_app = []

# Function to calculate combinations
def comb(n, r):
    return math.factorial(n) / (math.factorial(n - r) * math.factorial(r))

# Function to calculate probability
def p(n, r):
    return comb(n, r) / pow(2, n)

# Populate the lists with data
for i in range(num_min, num_max + 1):
    for j in range(2, i + 1):
        for k in range(0, j + 1):
            n_total_app.append(i)
            n_Ubi_app.append(j)
            n_Int_app.append(k)
            I_Ubi_app.append(- math.log(p(i, j), 2))
            I_Int_app.append(- math.log(p(i, k), 2))
            delta_app.append(- math.log(p(i, k), 2) + math.log(p(i, j), 2))

# Create DataFrame
n_total = pd.DataFrame(n_total_app, columns=['Total'])           
n_Ubi = pd.DataFrame(n_Ubi_app, columns=['Ubi'])
n_Int = pd.DataFrame(n_Int_app, columns=['Int'])
i_Ubi = pd.DataFrame(I_Ubi_app, columns=['Ubi Info'])
i_Int = pd.DataFrame(I_Int_app, columns=['Int Info'])
i_delta = pd.DataFrame(delta_app, columns=['Delta'])

# Combine all data into a single DataFrame
d = pd.concat([n_total, n_Ubi, n_Int, i_Ubi, i_Int, i_delta], axis=1, join="inner")

# Plotting
sns.set_style("darkgrid")

X = d['Total']
Y = d['Ubi Info']
Z = d['Int Info']
C = d['Delta']

fig = plt.figure(figsize=(15, 10))
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel("Total")
ax.set_ylabel("Ubi Info")
ax.set_zlabel("Int Info")


sc = ax.scatter(X, Y, Z, c=C, marker="o", s= 5, cmap = 'viridis')
plt.colorbar(sc, ax=ax, label='Delta')

plt.show()

# %%
import math
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# Define the range for total number of applications
num_min = 10
num_max = 40

# Initialize lists to store data
n_total_app = []
n_Ubi_app = []
n_Int_app = []
I_Ubi_app = []
I_Int_app = []
delta_app = []

# Function to calculate combinations
def comb(n, r):
    return math.factorial(n) / (math.factorial(n - r) * math.factorial(r))

# Function to calculate probability
def p(n, r):
    return comb(n, r) / pow(2, n)

# Populate the lists with data
for i in range(num_min, num_max + 1):
    for j in range(2, i + 1):
        for k in range(0, j + 1):
            n_total_app.append(i)
            n_Ubi_app.append(j)
            n_Int_app.append(k)
            I_Ubi_app.append(- math.log(p(i, j), 2))
            I_Int_app.append(- math.log(p(i, k), 2))
            delta_app.append(- math.log(p(i, k), 2) + math.log(p(i, j), 2))

# Create DataFrame
n_total = pd.DataFrame(n_total_app, columns=['Total'])           
n_Ubi = pd.DataFrame(n_Ubi_app, columns=['Ubi'])
n_Int = pd.DataFrame(n_Int_app, columns=['Int'])
i_Ubi = pd.DataFrame(I_Ubi_app, columns=['Ubi Info'])
i_Int = pd.DataFrame(I_Int_app, columns=['Int Info'])
i_delta = pd.DataFrame(delta_app, columns=['Delta'])

# Combine all data into a single DataFrame
d = pd.concat([n_total, n_Ubi, n_Int, i_Ubi, i_Int, i_delta], axis=1, join="inner")

# Plotting
sns.set_style("darkgrid")

X = d['Total']
Y = d['Ubi Info']
Z = d['Int Info']
C = d['Delta']  # Use Delta as color

# Create the figure and first subplot
fig = plt.figure(figsize=(15, 10))

# First subplot
ax1 = fig.add_subplot(121, projection='3d')
ax1.set_xlabel("Total")
ax1.set_ylabel("Ubi Info")
ax1.set_zlabel("Int Info")
sc1 = ax1.scatter(X, Y, Z, c=C, marker="o", s=5, cmap='viridis')
plt.colorbar(sc1, ax=ax1, label='Delta')

# Set the viewing angle for the first subplot
ax1.view_init(elev=30, azim=120)

# Second subplot
ax2 = fig.add_subplot(122, projection='3d')
ax2.set_xlabel("Total")
ax2.set_ylabel("Ubi Info")
ax2.set_zlabel("Int Info")
sc2 = ax2.scatter(X, Y, Z, c=C, marker="o", s=5, cmap='viridis')
plt.colorbar(sc2, ax=ax2, label='Delta')

# Set a different viewing angle for the second subplot
ax2.view_init(elev=60, azim=240)

plt.show()

# %%
import math
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# Define the range for total number of applications
num_min = 10
num_max = 40

# Initialize lists to store data
n_total_app = []
n_Ubi_app = []
n_Int_app = []
I_Ubi_app = []
I_Int_app = []
delta_app = []

# Function to calculate combinations
def comb(n, r):
    return math.factorial(n) / (math.factorial(n - r) * math.factorial(r))

# Function to calculate probability
def p(n, r):
    return comb(n, r) / pow(2, n)

# Populate the lists with data
for i in range(num_min, num_max + 1):
    for j in range(2, i + 1):
        for k in range(0, j + 1):
            n_total_app.append(i)
            n_Ubi_app.append(j)
            n_Int_app.append(k)
            I_Ubi_app.append(- math.log(p(i, j), 2))
            I_Int_app.append(- math.log(p(i, k), 2))
            delta_app.append(- math.log(p(i, k), 2) + math.log(p(i, j), 2))

# Create DataFrame
n_total = pd.DataFrame(n_total_app, columns=['Total'])           
n_Ubi = pd.DataFrame(n_Ubi_app, columns=['Ubi'])
n_Int = pd.DataFrame(n_Int_app, columns=['Int'])
i_Ubi = pd.DataFrame(I_Ubi_app, columns=['Ubi Info'])
i_Int = pd.DataFrame(I_Int_app, columns=['Int Info'])
i_delta = pd.DataFrame(delta_app, columns=['Delta'])

# Combine all data into a single DataFrame
d = pd.concat([n_total, n_Ubi, n_Int, i_Ubi, i_Int, i_delta], axis=1, join="inner")

# Plotting
sns.set_style("darkgrid")

X = d['Total']
Y = d['Ubi']
Z = d['Int']
C = d['Delta']

fig = plt.figure(figsize=(15, 10))
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel("Total")
ax.set_ylabel("Ubi")
ax.set_zlabel("Int")


sc = ax.scatter(X, Y, Z, c=C, marker="o", s= 3, cmap = 'viridis')
plt.colorbar(sc, ax=ax, label='Delta')

plt.show()
